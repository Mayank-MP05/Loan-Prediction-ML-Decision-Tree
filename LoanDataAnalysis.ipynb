# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
train = pd.read_csv("../input/loan-prediction-problem-dataset/train_u6lujuX_CVtuZ9i.csv")
test = pd.read_csv("../input/loan-prediction-problem-dataset/test_Y3wMUE5_7gLdaTN.csv")
print("Train")
train.head()
print("Test")
test.head()

# %%
test.shape
# Output Column is Missing

# %%
train.shape

# %%
#lets focus on training data
train.info()

# %%
# column indesx 6 to 10 are numerical data other are categotrical
train.describe()

# %%
train.isna().sum()

# %% [markdown]
# ##### Need to clean NanN and Null values for visualisation

# %%
train.dropna(inplace=True)

# %% [raw]
# train.isna().sum()

# %%
train.shape

# %% [markdown]
# ###### we deleted null entries for convienience

# %%
#lets plot the data and get insights of relativity or dependance of variables

# %%
train.Gender.value_counts().plot(kind="bar")

# %%
train.columns

# %% [markdown]
# Loan ID - Nothing to do with approval - Drop it

# %%
import seaborn as sb
sb.countplot(train['Property_Area'],hue=train['Loan_Status'])

# %%
sb.countplot(train['Gender'],hue=train['Loan_Status'])

# %% [markdown]
# ###### MAle have higher chance of approval of loan

# %%
sb.countplot(train['Married'],hue=train['Loan_Status'])

# %%
sb.countplot(train['Dependents'],hue=train['Loan_Status'])

# %% [markdown]
# ##### Zero Dependant is the best case to get the loan

# %%
train.columns

# %%
sb.countplot(train['Self_Employed'],hue=train['Loan_Status'])

# %%
sb.countplot(train['Credit_History'],hue=train['Loan_Status'])

# %% [markdown]
# ###### Credit History is highly important probable factor for loan approvalo

# %%
sb.countplot(train['Education'],hue=train['Loan_Status'])

# %% [markdown]
# ##### Lets draw most important sabka baap of analysis
# ## Corelation Matrix

# %%
train.corr()

# %%
# Drawing VColred Heatmap
train2 = train
# Converting Loan Status to Numerical Data
train2['Loan_Status'].replace('N',0,inplace=True)
train2['Loan_Status'].replace('Y',1,inplace=True)

train2.head()
# sb.heatmap(train2.corr())

# %%
 sb.heatmap(train2.corr(),annot=True)

# %% [markdown]
# ##### Heavy Dependance on Credit History And Not Other Numerical Data
